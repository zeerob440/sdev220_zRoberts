# %% [markdown]
# Assignment 3.1 - 3.6 Zachary Roberts

# %%
#3.1
seconds_in_minute = 60
minutes_in_hour = 60

# %%
#3.2
seconds_per_hour = minutes_in_hour * seconds_in_minute # result assigned in var seconds_in_hour.
print(f'There are {seconds_per_hour} seconds in an hour.')
# Out:
# There are 3600 seconds in an hour.

# %%
#3.3-3.4
hours_in_day = 24
seconds_per_day = hours_in_day * seconds_per_hour # result assigned to seconds_per_day.
print(f'There are {seconds_per_day} in a day.')
# Out:
# There are 86400 in a day.

# %%
#3.5-3.6
print(f'''Using floating point division results in an integer right of the decimal point such that second per day / seconds per hour results in: {seconds_per_day / seconds_per_hour}
Which is equal to seconds per day // seconds per hour results in a whole number such as: {seconds_per_day // seconds_per_hour}.''')
# Out:
# Using floating point division results in an integer right of the decimal point such that second per day / seconds per hour results in: 24.0
# Which is equal to seconds per day // seconds per hour results in a whole number such as: 24.
# 24
