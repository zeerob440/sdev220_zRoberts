# %% [markdown]
# 11.1 Create a file called zoo.py. In it, define a function called hours() that prints the string 'Open 9-5 daily'. Then, use the interactive interpreter to import the zoo module and call its hours() function.
#
# 11.2 In the interactive interpreter, import the zoo module as menagerie and call its hours() function.
#
# # need to do use 16.4 to do 16.8: 16.4 Use the sqlite3 module to create a SQLite database called books.db and a table called books with these fields: title (text), author (text), and year (integer).
#
#
# 16.8 Use the sqlalchemy module to connect to the sqlite3 database books.db that you just made in exercise 16.4. As in 16.6, select and print the title column from the book table in alphabetical order.

# %%
# 11.1
# zoo.py is declared in the root of my folder sdev_220_zroberts . The 11.1 program imports it to mod4ModulesDataBasesAssn

from zoo import hours

hours()
# Out:
# 'Open 9-5 daily'

# %%
#11.2
import zoo as menagerie 

hours()
# Out:
# 'Open 9-5 daily'

# %%
#16.4 

import sqlite3

bridge = sqlite3.connect("books.db")

cursor = bridge.cursor()

cursor.execute("""
               CREATE TABLE IF NOT EXISTS books (
               title TEXT,
               author TEXT,
               year INTEGER
)
""")

bridge.commit()
bridge.close()

books_db_there: str ='books.db is in sqlite3'

print(books_db_there)
# Out:
# books.db is in sqlite3

# %%
#16.8

from sqlalchemy import create_engine, text

engine = create_engine("sqlite///books.db")

with engine.connect() as bridge:
    result = bridge.execute(
        text("SELECT title FROM books ORDER by TITLE")
    )

for row in result:
    print(row[0])
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[3], line 5
#       1 #16.8
#       3 from sqlalchemy import create_engine, text
# ----> 5 engine = create_engine("sqlite///books.db")
#       7 with engine.connect() as bridge:
#       8     result = bridge.execute(
#       9         text("SELECT title FROM books ORDER by TITLE")
#      10     )
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\zeero\Desktop\GitHub\sdev220_zRoberts\venv\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File c:\Users\zeero\Desktop\GitHub\sdev220_zRoberts\venv\Lib\site-packages\sqlalchemy\engine\create.py:564, in create_engine(url, **kwargs)
#     561 kwargs.pop("empty_in_strategy", None)
#     563 # create url.URL object
# --> 564 u = _url.make_url(url)
#     566 u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     568 entrypoint = u._get_entrypoint()
#
# File c:\Users\zeero\Desktop\GitHub\sdev220_zRoberts\venv\Lib\site-packages\sqlalchemy\engine\url.py:856, in make_url(name_or_url)
#     840 """Given a string, produce a new URL instance.
#     841
#     842 The format of the URL generally follows `RFC-1738
#    (...)    852
#     853 """
#     855 if isinstance(name_or_url, str):
# --> 856     return _parse_url(name_or_url)
#     857 elif not isinstance(name_or_url, URL) and not hasattr(
#     858     name_or_url, "_sqla_is_testing_if_this_is_a_mock_object"
#     859 ):
#     860     raise exc.ArgumentError(
#     861         f"Expected string or URL object, got {name_or_url!r}"
#     862     )
#
# File c:\Users\zeero\Desktop\GitHub\sdev220_zRoberts\venv\Lib\site-packages\sqlalchemy\engine\url.py:922, in _parse_url(name)
#     919     return URL.create(name, **components)  # type: ignore
#     921 else:
# --> 922     raise exc.ArgumentError(
#     923         "Could not parse SQLAlchemy URL from given URL string"
#     924     )
#
# ArgumentError: Could not parse SQLAlchemy URL from given URL string
