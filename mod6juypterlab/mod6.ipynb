# %% [markdown]
# 13.1 Write the current date as a string to the text file today.txt.
#
# 13.2 Read the text file today.txt into the string today_string.
#
# 13.3 Parse the date from today_string.
#
# 15.1 Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between zero and one, print the current time, and then exit.

# %%
# 13.1
from datetime import datetime 

mil_date: str = datetime.today().strftime("%d-%b-%Y").upper()

with open("today.txt", "w") as file:
    file.write(mil_date)

# print check
# print(mil_date)
# correct string saved in today.txt
# Out:
# 16-FEB-2026
# today.txt

# %%
# 13.2

with open("today.txt", 'r') as file:
    today_string = file.read()

# print check
# print(today_string)
# correct value read in today_string

# %%
#13.3 

from datetime import datetime

# parse the today_string

parsed_today_string: str = datetime.strptime(today_string, "%d-%b-%Y")

most_logical_format: str = "The most logical date format increments from smallest unit of time to largest, like numbers."
parsed_today_string_day: str = f" The day is: {parsed_today_string.day}."
parsed_today_string_month: str = f" The month is: {parsed_today_string.month}."
parsed_today_string_year: str = f" The year is: {parsed_today_string.year}."

print(most_logical_format + parsed_today_string_day + parsed_today_string_month + parsed_today_string_year)
# Out:
# The most logical date format increments from smallest unit of time to largest, like numbers. The day is: 16. The month is: 2. The year is: 2026.

# %%
#15.1 Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between zero and one, print the current time, and then exit.

import random
from datetime import datetime
import multiprocessing
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[26], line 7
#       4 from datetime import datetime
#       5 import subprocess
# ----> 7 test = subprocess.call("today.txt")
#
# File c:\Users\zeero\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:395, in call(timeout, *popenargs, **kwargs)
#     387 def call(*popenargs, timeout=None, **kwargs):
#     388     """Run command with arguments.  Wait for command to complete or
#     389     timeout, then return the returncode attribute.
#     390
#    (...)
#     393     retcode = call(["ls", "-l"])
#     394     """
# --> 395     with Popen(*popenargs, **kwargs) as p:
#     396         try:
#     397             return p.wait(timeout=timeout)
#
# File c:\Users\zeero\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1036, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1032         if self.text_mode:
#    1033             self.stderr = io.TextIOWrapper(self.stderr,
#    1034                     encoding=encoding, errors=errors)
# -> 1036     self._execute_child(args, executable, preexec_fn, close_fds,
#    1037                         pass_fds, cwd, env,
#    1038                         startupinfo, creationflags, shell,
#    1039                         p2cread, p2cwrite,
#    1040                         c2pread, c2pwrite,
#    1041                         errread, errwrite,
#    1042                         restore_signals,
#    1043                         gid, gids, uid, umask,
#    1044                         start_new_session, process_group)
#    1045 except:
#    1046     # Cleanup if the child failed starting.
#    1047     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\zeero\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1548, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1546 # Start the process
#    1547 try:
# -> 1548     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1549                              # no special security
#    1550                              None, None,
#    1551                              int(not close_fds),
#    1552                              creationflags,
#    1553                              env,
#    1554                              cwd,
#    1555                              startupinfo)
#    1556 finally:
#    1557     # Child is launched. Close the parent's copy of those pipe
#    1558     # handles that only the child should have open.  You need
#    (...)
#    1561     # pipe will not close when the child process exits and the
#    1562     # ReadFile will hang.
#    1563     self._close_pipe_fds(p2cread, p2cwrite,
#    1564                          c2pread, c2pwrite,
#    1565                          errread, errwrite)
#
# OSError: [WinError 193] %1 is not a valid Win32 application
